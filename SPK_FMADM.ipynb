# %%
# Fungsi keanggotaan IPK
def membership_ipk(ipk):
    if ipk >= 3.75 and ipk <= 3.9:
        return (ipk - 3.75) / (3.9 - 3.75),
    elif ipk >= 3.0 and ipk <= 3.4:
        return (ipk - 3.0) / (3.4 - 3.0),
    elif ipk >= 3.5 and ipk <= 3.74:
        return (ipk - 3.5) / (3.74 - 3.5),
    else:
        return 1,

# Fungsi keanggotaan Kondisi Keluarga
def membership_kondisi_keluarga(penghasilan):
    if kondisi_keluarga >= 6000000 and kondisi_keluarga <= 10000000:
        return (kondisi_keluarga - 6000000) / (10000000 - 6000000),
    elif kondisi_keluarga >= 2000000 and kondisi_keluarga <= 5000000:
        return (kondisi_keluarga - 2000000) / (5000000 - 2000000),
    elif kondisi_keluarga >= 500000 and kondisi_keluarga <= 1000000:
        return (kondisi_keluarga - 500000) / (1000000 - 500000),
    else:
        return 0,

# Fungsi keanggotaan Penghasilan Kotor
def membership_penghasilan_kotor(penghasilan):
    if penghasilan_kotor >= 3000000 and penghasilan_kotor <= 12000000:
        return (penghasilan_kotor - 3000000) / (12000000 - 3000000),
    elif 1000000 <= penghasilan_kotor <= 2000000:
        return (penghasilan_kotor - 1000000) / (2000000-1000000),
    elif penghasilan_kotor >= 200000 and penghasilan_kotor <= 900000:
        return (penghasilan_kotor - 200000) / (900000 - 200000),

# Fungsi keanggotaan Keaktifan di bidang organisasi
def membership_keaktifan(keaktifan):
    if keaktifan == 'A':
        return (5-4)/(5-4),
    elif keaktifan == 'B' and 'C':
        return (4-1)/5,
    elif keaktifan == 'D' and 'E':
        return (3-1)/5,
    else:
        return 0,

# Fungsi keanggotaan Prestasi yang diperoleh
def membership_prestasi(prestasi):
    if prestasi == 5 and 4:
        return (prestasi - 4),
    elif prestasi >= 2 and prestasi <= 3:
        return (prestasi - 2) / (3 - 2),
    elif prestasi == 1:
        return (prestasi)/ 5,
    else:
        return 0,

# Fungsi keanggotaan ordik & LDK
def membership_ordik_ldk(ordik_ldk):
    if ordik_ldk >= 81 and ordik_ldk <= 100:
        return (ordik_ldk - 81) / (100 - 81),
    elif ordik_ldk >= 61 and ordik_ldk <= 80:
        return (ordik_ldk - 61) / (80 - 61),
    else:
        return (ordik_ldk - 10) / (60 - 10),

# Data kandidat
kandidat_data = [
        (1, "Vani", 3.77,	2000000,	3000000,	"B",	2,	61),
        (2, "Fikri", 4.00,	600000,	700000,	"A",	5,	75),
        (3, "Ardan", 3.25,	4000000,	5000000,	"D",	1,	50),
        (4, "Julio", 3.75,	700000,	800000,	"B",	2,	81),
        (5, "Budi", 3.90,	5000000,	6000000,	"B",	4,	85),
        (6, "Eka", 3.50,	4000000,	7000000,	"B",	4,	60),
        (7, "Intan", 3.00,	1000000,	2000000,	"D",	1,	40),
        (8, "Wahyu", 3.40,	750000,	1000000,	"C",	1,	70),
        (9, "Yasmin", 4.00,	6000000,	7000000,	"A",	3,	81),
        (10, "Kartini", 3.50,	850000,	1000000,	"B",	1,	65),
        (11, "Haris", 3.40,	6000000,	7000000,	"B",	2,	75),
        (12, "Pranata", 3.25,	5000000,	6000000,	"C",	1,	50),
        (13, "Widi", 4.00,	6000000,	7000000,	"A",	5,	95),
        (14, "Cinta", 4.00,	8000000,	9000000,	"A",	2,	86),
        (15, "Ahmad", 3.70,	700000,	900000,	"B",	3,	77)
]

# Menghitung nilai keanggotaan untuk setiap kandidat
for kandidat in kandidat_data:
    ipk, kondisi_keluarga, penghasilan_kotor, keaktifan, prestasi, ordik_ldk = kandidat[2:]
    keanggotaan_ipk = membership_ipk(ipk)
    keanggotaan_kondisi_keluarga = membership_kondisi_keluarga(kondisi_keluarga)
    keanggotaan_penghasilan_kotor = membership_penghasilan_kotor(penghasilan_kotor)
    keanggotaan_keaktifan = membership_keaktifan(keaktifan)
    keanggotaan_prestasi = membership_prestasi(prestasi)
    keanggotaan_ordik_ldk = membership_ordik_ldk(ordik_ldk)

    print(f"Kandidat {kandidat[0]} ({kandidat[1]}):")
    print(f"  IPK: {keanggotaan_ipk}")
    print(f"  Kondisi Keluarga: {keanggotaan_kondisi_keluarga}")
    print(f"  Penghasilan Kotor: {keanggotaan_penghasilan_kotor}")
    print(f"  Keaktifan: {keanggotaan_keaktifan}")
    print(f"  Prestasi: {keanggotaan_prestasi}")
    print(f"  ORDIK & LDK: {keanggotaan_ordik_ldk}")
    print()
# Out:
# Kandidat 1 (Vani):
#   IPK: (0.13333333333333353,)
#   Kondisi Keluarga: (0.0,)
#   Penghasilan Kotor: (0.0,)
#   Keaktifan: (0.6,)
#   Prestasi: (0.0,)
#   ORDIK & LDK: (0.0,)
#
# Kandidat 2 (Fikri):
#   IPK: (1,)
#   Kondisi Keluarga: (0.2,)
#   Penghasilan Kotor: (0.7142857142857143,)
#   Keaktifan: (1.0,)
#   Prestasi: (1,)
#   ORDIK & LDK: (0.7368421052631579,)
#
# Kandidat 3 (Ardan):
#   IPK: (0.6250000000000001,)
#   Kondisi Keluarga: (0.6666666666666666,)
#   Penghasilan Kotor: (0.2222222222222222,)
#   Keaktifan: (0.4,)
#   Prestasi: (0.2,)
#   ORDIK & LDK: (0.8,)
#
# Kandidat 4 (Julio):
#   IPK: (0.0,)
#   Kondisi Keluarga: (0.4,)
#   Penghasilan Kotor: (0.8571428571428571,)
#   Keaktifan: (0.6,)
#   Prestasi: (0.0,)
#   ORDIK & LDK: (0.0,)
#
# Kandidat 5 (Budi):
#   IPK: (1.0,)
#   Kondisi Keluarga: (0,)
#   Penghasilan Kotor: (0.3333333333333333,)
#   Keaktifan: (0.6,)
#   Prestasi: (0,)
#   ORDIK & LDK: (0.21052631578947367,)
#
# Kandidat 6 (Eka):
#   IPK: (0.0,)
# ...

# %%
# Bobot untuk setiap kriteria
bobot = {
    'IPK': 0.25,
    'Kondisi_Keluarga': 0.2,
    'Penghasilan_Kotor': 0.1,
    'Keaktifan_di_Bidang_Organisasi': 0.1,
    'Prestasi_yang_Diperoleh': 0.25,
    'ORDIK_&_LDK': 0.1
}

# List kosong untuk menyimpan hasil yang telah dikalikan dengan bobot
hasil_dikalikan_dengan_bobot = []

# Menghitung hasil yang telah dikalikan dengan bobot untuk setiap kandidat
for kandidat in kandidat_data:
    ipk, kondisi_keluarga, penghasilan_kotor, keaktifan, prestasi, ordik_ldk = kandidat[2:]
    keanggotaan_ipk = membership_ipk(ipk)[0] * bobot['IPK']
    keanggotaan_kondisi_keluarga = membership_kondisi_keluarga(kondisi_keluarga)[0] * bobot['Kondisi_Keluarga']
    keanggotaan_penghasilan_kotor = membership_penghasilan_kotor(penghasilan_kotor)[0] * bobot['Penghasilan_Kotor']
    keanggotaan_keaktifan = membership_keaktifan(keaktifan)[0] * bobot['Keaktifan_di_Bidang_Organisasi']
    keanggotaan_prestasi = membership_prestasi(prestasi)[0] * bobot['Prestasi_yang_Diperoleh']
    keanggotaan_ordik_ldk = membership_ordik_ldk(ordik_ldk)[0] * bobot['ORDIK_&_LDK']

    hasil_dikalikan_dengan_bobot.append([keanggotaan_ipk, keanggotaan_kondisi_keluarga, keanggotaan_penghasilan_kotor,
                                         keanggotaan_keaktifan, keanggotaan_prestasi, keanggotaan_ordik_ldk])

# Menampilkan hasil
for i, hasil in enumerate(hasil_dikalikan_dengan_bobot, start=1):
    print(f"Kandidat {i}: {hasil}")
# Out:
# Kandidat 1: [0.03333333333333338, 0.0, 0.0, 0.06, 0.0, 0.0]
# Kandidat 2: [0.25, 0.04000000000000001, 0.07142857142857144, 0.1, 0.25, 0.07368421052631578]
# Kandidat 3: [0.15625000000000003, 0.13333333333333333, 0.022222222222222223, 0.04000000000000001, 0.05, 0.08000000000000002]
# Kandidat 4: [0.0, 0.08000000000000002, 0.08571428571428572, 0.06, 0.0, 0.0]
# Kandidat 5: [0.25, 0.0, 0.03333333333333333, 0.06, 0.0, 0.021052631578947368]
# Kandidat 6: [0.0, 0.13333333333333333, 0.044444444444444446, 0.06, 0.0, 0.1]
# Kandidat 7: [0.0, 0.0, 0.1, 0.04000000000000001, 0.05, 0.06]
# Kandidat 8: [0.25, 0.1, 0.0, 0.0, 0.05, 0.04736842105263158]
# Kandidat 9: [0.25, 0.0, 0.044444444444444446, 0.1, 0.25, 0.0]
# Kandidat 10: [0.0, 0.13999999999999999, 0.0, 0.06, 0.05, 0.021052631578947368]
# Kandidat 11: [0.25, 0.0, 0.044444444444444446, 0.06, 0.0, 0.07368421052631578]
# Kandidat 12: [0.15625000000000003, 0.0, 0.03333333333333333, 0.0, 0.05, 0.08000000000000002]
# ...

# %%
# Bobot untuk setiap kriteria
bobot = {
    'IPK': 0.25,
    'Kondisi_Keluarga': 0.2,
    'Penghasilan_Kotor': 0.1,
    'Keaktifan_di_Bidang_Organisasi': 0.1,
    'Prestasi_yang_Diperoleh': 0.25,
    'ORDIK_&_LDK': 0.1
}

# List kosong untuk menyimpan hasil yang telah dikalikan dengan bobot
hasil_dikalikan_dengan_bobot = []

# Menghitung hasil yang telah dikalikan dengan bobot untuk setiap kandidat
for kandidat in kandidat_data:
    ipk, kondisi_keluarga, penghasilan_kotor, keaktifan, prestasi, ordik_ldk = kandidat[2:]
    keanggotaan_ipk = membership_ipk(ipk)[0] * bobot['IPK']
    keanggotaan_kondisi_keluarga = membership_kondisi_keluarga(kondisi_keluarga)[0] * bobot['Kondisi_Keluarga']
    keanggotaan_penghasilan_kotor = membership_penghasilan_kotor(penghasilan_kotor)[0] * bobot['Penghasilan_Kotor']
    keanggotaan_keaktifan = membership_keaktifan(keaktifan)[0] * bobot['Keaktifan_di_Bidang_Organisasi']
    keanggotaan_prestasi = membership_prestasi(prestasi)[0] * bobot['Prestasi_yang_Diperoleh']
    keanggotaan_ordik_ldk = membership_ordik_ldk(ordik_ldk)[0] * bobot['ORDIK_&_LDK']

    # Menjumlahkan hasil yang telah dikalikan dengan bobot untuk setiap kandidat
    total_hasil_dikalikan_dengan_bobot = sum([keanggotaan_ipk, keanggotaan_kondisi_keluarga, keanggotaan_penghasilan_kotor,
                                              keanggotaan_keaktifan, keanggotaan_prestasi, keanggotaan_ordik_ldk])

    hasil_dikalikan_dengan_bobot.append(total_hasil_dikalikan_dengan_bobot)
# Menampilkan hasil
for i, total_hasil in enumerate(hasil_dikalikan_dengan_bobot, start=1):
    print(f"Total Hasil Kandidat {i}: {total_hasil}")
# Out:
# Total Hasil Kandidat 1: 0.09333333333333338
# Total Hasil Kandidat 2: 0.7851127819548873
# Total Hasil Kandidat 3: 0.4818055555555556
# Total Hasil Kandidat 4: 0.22571428571428573
# Total Hasil Kandidat 5: 0.3643859649122807
# Total Hasil Kandidat 6: 0.3377777777777778
# Total Hasil Kandidat 7: 0.25
# Total Hasil Kandidat 8: 0.4473684210526315
# Total Hasil Kandidat 9: 0.6444444444444445
# Total Hasil Kandidat 10: 0.2710526315789474
# Total Hasil Kandidat 11: 0.42812865497076025
# Total Hasil Kandidat 12: 0.3195833333333334
# Total Hasil Kandidat 13: 0.7181286549707603
# Total Hasil Kandidat 14: 0.5429824561403508
# Total Hasil Kandidat 15: 0.7825438596491228
